# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjanapasula/aiml/blob/main/part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as mpt
people=["kiran", "arun", "vijay", "varun"]
age=[25,30,35,40]
height=[145,151,165,173]
weight=[45,55,65,75]
mpt.scatter(weight, height,color='black')
mpt.title("graph on height and weight")
mpt.xlabel("weight in kgs")
mpt.ylabel("height in meters")
mpt.show()

# %%
import matplotlib.pyplot as mpt
people=["kiran", "arun", "vijay", "varun"]

height=[145,151,165,173]

mpt.bar(people, height,color="green", width=0.5)

mpt.title("bar chart")

mpt.xlabel("age in years")

mpt.ylabel("height in meters")

mpt.show()

# %%
import matplotlib.pyplot as plt
age=[25,30,35,40]
weight=[45,55,65,75]
plt.xlabel("age in years")
plt.ylabel("weight in kgs")
plt.title("histogram of age and weight")
plt.show()

plt.hist(age, bins=5, alpha=0.3)
plt.hist(weight, bins=5, alpha=0.2)
# Out:
# (array([1., 1., 0., 1., 1.]),
#  array([45., 51., 57., 63., 69., 75.]),
#  <BarContainer object of 5 artists>)
